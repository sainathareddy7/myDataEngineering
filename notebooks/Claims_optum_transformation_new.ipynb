# %%
#print ("Hello")

# %%
# List all secret scopes
#dbutils.secrets.listScopes()

# %%
# List all keys in the 'optumscope' scope
#dbutils.secrets.list("optumscope")

# %%
# %run /Workspace/Users/az_data_eng_25@outlook.com/genric_connectors

# %%
# %run /Workspace/Users/az_data_eng_25@outlook.com/generic_transformations

# %%
spark_connector()
# Out:
# 'Connected to adls'

# %%
#%python
#spark.conf.set(    "fs.azure.account.key.optumadlssg.dfs.core.windows.net",    "9AGjrKbH3Fyag2kBwQ5xiSQ1baXjdCVuG8AXmPXiBGJ5E0UwY9hmL3jcCAIAw/l6fjax+90VSSS0+ASte3LsvQ==")

# %%
# %python
spark.conf.set(
    "fs.azure.account.key.optumadlssg.dfs.core.windows.net",
    dbutils.secrets.get(scope = 'optumscope', key = 'adlskey'))

# %%
#display(dbutils.fs.ls("abfss://optum@optumadlssg.dfs.core.windows.net/"))

# %%
#display(dbutils.fs.ls("abfss://optum@optumadlssg.dfs.core.windows.net/bronze"))

# %%
#claim_df = spark.read.csv("abfss://optum@optumadlssg.dfs.core.windows.net/bronze/Claims.json",inferSchema=True,header=True)

# %%
claim_df= read_bronze_csv_data("Claims.json")

# %%
#dbutils.fs.ls(
  #"abfss://optum@optumadlssg.dfs.core.windows.net/bronze/"
#)

# %%
claim_df = spark.read.json("abfss://optum@optumadlssg.dfs.core.windows.net/bronze/Claims.json")
display(claim_df)
#claim_df = spark.read.json("abfss://optum@optumadlssg.dfs.core.windows.net/bronze/Claims.json")
#display(claim_df)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6323469034018034>, line 2
#       1 claim_df = spark.read.json("abfss://optum@optumadlssg.dfs.core.windows.net/bronze/Claims.json")
# ----> 2 display(claim_df)
#
# File /databricks/python_shell/lib/dbruntime/display.py:133, in Display.display(self, input, *args, **kwargs)
#     131     self.display_connect_table(input, **kwargs)
#     132 elif isinstance(input, ConnectDataFrame):
# --> 133     if input.isStreaming:
#     134         handleStreamingConnectDataFramePy4j(input, self.entry_point, kwargs)
#     135     else:
#
# File /usr/lib/python3.12/functools.py:995, in cached_property.__get__(self, instance, owner)
#     993 val = cache.get(self.attrname, _NOT_FOUND)
#     994 if val is _NOT_FOUND:
# --> 995     val = self.func(instance)
#     996     try:
#     997         cache[self.attrname] = val
#
# ...

# %%
display(claim_df)

# %%
df_row_columns_cnt(claim_df)

# %%
#grp_df=grp_df.replace("NaN",None)

# %%
df_missing_value_cnt(claim_df)

# %%
missing_value_perc(claim_df)

# %%
check_duplicate(claim_df)

# %%
claim_df =claim_df.drop("_id")
claim_df=claim_df.replace("NaN",None)
claim_df=claim_df.withColumn("claim_amount",claim_df["claim_amount"].cast(DoubleType()))
claim_df=claim_df.withColumn("claim_date",to_date(claim_df["claim_date"],"yyyy-MM-dd"))
claim_df= claim_df.fillna({'Claim_Or_Rejected':'N'})

# %%
display(claim_df)

# %%
write2silver(claim_df,"Claims_s.csv")

# %%
display(claim_df.select("*").filter(col('Sub_ID').isin(['SUBID10022','SUBID10049'
])))
